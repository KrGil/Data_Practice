# %%
import numpy as np
import pandas as pd

# %%
pd.Series([10, 20, 30])
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
 df = pd.read_csv('gapminder.csv', index_col = 'Unnamed: 0' )

# %%
df.head()
# Out:
#    year continent                 country   income  life_exp   population
# 0  2014      asia             Philippines   6598.0      70.7  100102249.0
# 1  2014  americas                Paraguay   8038.0      74.3    6552584.0
# 2  2014      asia                   Palau  14078.0       NaN      21094.0
# 3  2014      asia                Pakistan   4619.0      65.6  185546257.0
# 4  2014  americas  St.-Pierre-et-Miquelon      NaN       NaN       6277.0

# %%
df['income'][:5]
# Out:
# 0     6598.0
# 1     8038.0
# 2    14078.0
# 3     4619.0
# 4        NaN
# Name: income, dtype: float64

# %%
df['population'][:5]
# Out:
# 0    100102249.0
# 1      6552584.0
# 2        21094.0
# 3    185546257.0
# 4         6277.0
# Name: population, dtype: float64

# %%
df['gross_income'] = df['income'] * df['population']

# %%
df
# Out:
#        year continent                         country    income  life_exp  \
# 0      2014      asia                     Philippines    6598.0     70.70
# 1      2014  americas                        Paraguay    8038.0     74.30
# 2      2014      asia                           Palau   14078.0       NaN
# 3      2014      asia                        Pakistan    4619.0     65.60
# 4      2014  americas          St.-Pierre-et-Miquelon       NaN       NaN
# 5      2014  americas                          Brazil   15412.0     74.30
# 6      2014    europe                          Norway   64020.0     82.00
# 7      2014    africa                         Nigeria    5607.0     63.70
# 8      2014  americas                       Nicaragua    4574.0     77.80
# 9      2014    europe                     Netherlands   45281.0     81.30
# 10     2014      asia                Papua New Guinea    2510.0     60.50
# 11     2014      asia                          Taiwan   41376.0     79.40
# ...
